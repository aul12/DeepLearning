# %% [markdown]
# # Exercise 4

# %% [markdown]
# In this exercise, we will work with the MNIST dataset. The dataset contains images of hand-written digits, along with the ground-truth labels (the digit that an image represents).

# %%
from torchvision.datasets import MNIST

# %% [markdown]
# The MNIST dataset is structured into a training set and a validation set, which we can load separately:

# %%
train_data = MNIST('.', download=True, train=True)
val_data = MNIST('.', download=True, train=False)

# %% [markdown]
# We can inspect the structure of the dataset:

# %%
print("len(train_data):", len(train_data))
print("len(val_data):", len(val_data))
print()
first_sample = train_data[0]
print("type(first_sample):", type(first_sample))
print("len(first_sample):", len(first_sample))
print("type(first_sample[0]):", type(first_sample[0]))
print("type(first_sample[1]):", type(first_sample[1]))
print()

image = first_sample[0]
label = first_sample[1]

print("Image size:", image.size)
print("Label:", label)
# Out:
# len(train_data): 60000
# len(val_data): 10000
#
# type(first_sample): <class 'tuple'>
# len(first_sample): 2
# type(first_sample[0]): <class 'PIL.Image.Image'>
# type(first_sample[1]): <class 'int'>
#
# Image size: (28, 28)
# Label: 5

# %% [markdown]
# As we can see, we can load samples from the dataset with the `[]` operator, and each sample is a tuple with an image and the corresponding label.

# %% [markdown]
# ## Plotting the data

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Visualizing the data is always a good idea:

# %%
fig, axes = plt.subplots(5, 5, figsize=(14, 14))
for i in range(25):
    image, label = train_data[i]
    ax = axes[i//5, i%5]
    ax.imshow(image)
    ax.set_title(f"Label: {label}", fontdict={"fontsize": 14})
plt.tight_layout()
plt.show()

# %% [markdown]
# ## LeNet implementation

# %% [markdown]
# We will use a quite simple network to learn digit recognition. The LeNet architecture has just two convolutional layers and two linear layers, along with a couple of nonlinear activations and two pooling layers. The following code implements the network using PyTorch:

# %%
import torch
from torch import nn

class LeNet(nn.Module):
    def __init__(self, num_classes, input_shape):
        super(LeNet, self).__init__()

        # first convolution layer + activation + max pooling
        self.conv1 = nn.Conv2d(input_shape[0], 20, (5, 5))
        self.act1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2)
        self.bn1 = nn.BatchNorm2d(20)
        
        # second convolution layer + activation + max pooling
        self.conv2 = nn.Conv2d(20, 50, (5, 5))
        self.act2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2)
        self.bn2 = nn.BatchNorm2d(50)
        
        # first linear layer + activation
        self.conv_output_len = (50*4*4)
        self.linear1 = nn.Linear(self.conv_output_len, 500)
        self.act3 = nn.ReLU()
        
        self.dropout = nn.Dropout()
        
        # final linear layer to produce the correct number of outputs
        self.linear2 = nn.Linear(500, num_classes)

    def forward(self, x):
        # perform convolution -> activation -> pooling
        x = self.bn1(self.pool1(self.act1(self.conv1(x))))
        x = self.bn2(self.pool2(self.act2(self.conv2(x))))
        
        # flatten the features obtained from the conv layers: (BATCH_SIZE, 50, 4, 4) -> (BATCH_SIZE, 50*4*4)
        batch_size = x.shape[0]
        x = x.view(batch_size, self.conv_output_len)
        
        # final linear layers and activations
        x = self.dropout(self.act3(self.linear1(x)))
        x = self.linear2(x)
        
        return x

# %% [markdown]
# Some notable changes from the LeNet implementation in the original paper are the use of ReLU instead of sigmoid/tanh activations, use of Max Pooling instead of Average Pooling and the number of filters / parameters used in the layers (to allow direct application to the MNIST images without upscaling to 32x32 pixels).
#
# Note that the network does not contain a softmax activation on the final layer, as we will use the `cross_entropy` loss function from PyTorch lateron, which works on the raw logits directly, and yields incorrect results when a softmax operation is applied beforehand.

# %% [markdown]
# ## Torchvision version check

# %% [markdown]
# torchvision < 0.6.0 has a bug when using the RandomRotation class (see https://github.com/pytorch/vision/pull/1828), which is required for one of the tasks below. The following code checks if you are using a recent version of torchvision. If it prints out that you should upgrade, make sure to install the latest torchvision with pip or conda (see setup_instructions.pdf from exercise 1)!

# %%
import torchvision
from packaging import version
import logging

print("torchvision version:", torchvision.__version__)
if version.parse(torchvision.__version__) < version.parse('0.6.0a0'):
    logging.error("You seem to be running an old version of torchvision, please upgrade to the latest version!")
else:
    print("torchvision version seems to be fine.")
# Out:
# torchvision version: 0.6.0
# torchvision version seems to be fine.

# %% [markdown]
# ## Training

# %% [markdown]
# The following code implements a training and validation loop. In each epoch, one iteration over the training set is performed, followed by one iteration over the validation set. This allows us to check the training and validation loss and classification accuracy in each epoch, which is useful to spot overfitting.
#
# As the point of this exercise is to show you the effect of overfitting and how to combat it, we use only a very small subset of the training data. This leads to the network quickly overfitting quite heavily on the training data and thus not generalizing.

# %%
from torchvision.transforms import ToTensor, RandomRotation, Compose
from torch.nn.functional import cross_entropy
import numpy as np
import tqdm
from math import ceil
import random

NUM_EPOCHS = 100
BATCH_SIZE = 10
NUM_CLASSES = 10
LR = 0.001

random.seed(0)
torch.manual_seed(0)
model = LeNet(NUM_CLASSES, (1, 28, 28))
device = "cuda" if torch.cuda.is_available() else "cpu"
model.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=LR, weight_decay=0.001)

num_train_images = 100 # len(train_data)
num_val_images = 100 # len(val_data)

train_losses = []
val_losses = []
train_accuracy = []
val_accuracy = []

BATCH_SIZE = 50

# This loader generates batches of data according to BATCH_SIZE
# It also applies a `transform` function to the image (see below)
def Loader(data, num_samples, transform, BATCH_SIZE=BATCH_SIZE):
    NUM_BATCHES = int(ceil(num_samples/BATCH_SIZE))
    
    # This generates the batches, one after another
    for i in range(NUM_BATCHES):
        indices = range(i*BATCH_SIZE, min((i+1)*BATCH_SIZE, num_samples))
        batch = [data[i] for i in indices]
        
        # convert PIL image and label to PyTorch tensors
        images = torch.stack([transform(item[0]) for item in batch])
        labels = torch.stack([torch.tensor(item[1]) for item in batch])
        yield images, labels

# Image transforms
# ToTensor converts a PIL image to a PyTorch tensor
# It also swaps the order of the image channels, e.g. (28, 28, 3) to (3, 28, 28)
# Also, the pixel values are normalized to be between 0 and 1 (instead of between 0 and 255)
# See https://pytorch.org/docs/stable/torchvision/transforms.html#torchvision.transforms.ToTensor
train_transform = Compose([RandomRotation(30), ToTensor()])
val_transform = ToTensor()

for epoch in range(NUM_EPOCHS):
    # perform training followed by validation
    for mode, data, num_samples, transform in [
        ("train", train_data, num_train_images, train_transform),
        ("val", val_data, num_val_images, val_transform)
    ]:
        # progressbar setup
        num_batches = int(ceil(num_samples/BATCH_SIZE))
        pbar = tqdm.tqdm(total=num_batches, desc=f"{mode} epoch {epoch}")

        if mode == "train":
            model.train() # do calculate gradients for training mode
        else:
            model.eval() # do not calculate gradients in validation mode

        # initial values of the metrics (loss, accurracy)
        runningLoss = 0.
        correct_predictions = 0
        # total number of images that were processed
        total_samples = 0
        
        # loop over the data
        for i_batch, batch in enumerate(Loader(data, num_samples, transform)):
            images, labels = batch
            # move tensors to the correct device
            images = images.to(device)
            labels = labels.to(device)

            # run the model
            predictions = model.forward(images)

            # loss calculation
            loss = cross_entropy(predictions, labels)

            # calculate the metrics for the progress bar
            num_batch_samples = len(images)
            runningLoss += loss.item() * num_batch_samples
            correct_predictions += (torch.argmax(predictions, dim=-1) == labels).sum().item()
            total_samples += num_batch_samples
            
            pbar.update(1)
            pbar.set_postfix({
                "loss": runningLoss / total_samples,
                "accuracy": correct_predictions / total_samples
            })

            # weight update
            if mode == "train":
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
        epoch_loss = runningLoss / total_samples
        epoch_accuracy = correct_predictions / total_samples
        if mode == "train":
            train_losses.append(epoch_loss)
            train_accuracy.append(epoch_accuracy)
        else:
            val_losses.append(epoch_loss)
            val_accuracy.append(epoch_accuracy)

        pbar.close()
# Out:
# train epoch 0: 100%|██████████| 2/2 [00:00<00:00, 85.06it/s, loss=2.2, accuracy=0.2]
# val epoch 0: 100%|██████████| 2/2 [00:00<00:00, 204.72it/s, loss=2.26, accuracy=0.5]
# train epoch 1: 100%|██████████| 2/2 [00:00<00:00, 83.40it/s, loss=1.52, accuracy=0.6]
# val epoch 1: 100%|██████████| 2/2 [00:00<00:00, 150.28it/s, loss=2.17, accuracy=0.58]
# train epoch 2: 100%|██████████| 2/2 [00:00<00:00, 109.30it/s, loss=1.09, accuracy=0.71]
# val epoch 2: 100%|██████████| 2/2 [00:00<00:00, 211.99it/s, loss=2.05, accuracy=0.48]
# train epoch 3: 100%|██████████| 2/2 [00:00<00:00, 101.36it/s, loss=0.776, accuracy=0.84]
# val epoch 3: 100%|██████████| 2/2 [00:00<00:00, 160.25it/s, loss=1.93, accuracy=0.34]
# train epoch 4: 100%|██████████| 2/2 [00:00<00:00, 116.44it/s, loss=0.583, accuracy=0.87]
# val epoch 4: 100%|██████████| 2/2 [00:00<00:00, 208.39it/s, loss=1.84, accuracy=0.31]
# train epoch 5: 100%|██████████| 2/2 [00:00<00:00, 101.52it/s, loss=0.457, accuracy=0.9]
# val epoch 5: 100%|██████████| 2/2 [00:00<00:00, 192.42it/s, loss=1.78, accuracy=0.29]
# train epoch 6: 100%|██████████| 2/2 [00:00<00:00, 102.21it/s, loss=0.283, accuracy=0.96]
# val epoch 6: 100%|██████████| 2/2 [00:00<00:00, 226.44it/s, loss=1.76, accuracy=0.3]
# train epoch 7: 100%|██████████| 2/2 [00:00<00:00, 96.52it/s, loss=0.28, accuracy=0.92]
# val epoch 7: 100%|██████████| 2/2 [00:00<00:00, 165.31it/s, loss=1.82, accuracy=0.29]
# train epoch 8: 100%|██████████| 2/2 [00:00<00:00, 96.61it/s, loss=0.219, accuracy=0.96]
# val epoch 8: 100%|██████████| 2/2 [00:00<00:00, 148.66it/s, loss=1.93, accuracy=0.28]
# train epoch 9: 100%|██████████| 2/2 [00:00<00:00, 115.78it/s, loss=0.192, accuracy=0.97]
# val epoch 9: 100%|██████████| 2/2 [00:00<00:00, 160.27it/s, loss=2.07, accuracy=0.29]
# train epoch 10: 100%|██████████| 2/2 [00:00<00:00, 85.50it/s, loss=0.139, accuracy=0.97]
# val epoch 10: 100%|██████████| 2/2 [00:00<00:00, 139.65it/s, loss=2.16, accuracy=0.31]
# train epoch 11: 100%|██████████| 2/2 [00:00<00:00, 91.51it/s, loss=0.126, accuracy=0.97]
# val epoch 11: 100%|██████████| 2/2 [00:00<00:00, 192.47it/s, loss=2.17, accuracy=0.32]
# train epoch 12: 100%|██████████| 2/2 [00:00<00:00, 98.41it/s, loss=0.155, accuracy=0.97]
# val epoch 12: 100%|██████████| 2/2 [00:00<00:00, 188.17it/s, loss=2.11, accuracy=0.35]
# train epoch 13: 100%|██████████| 2/2 [00:00<00:00, 103.42it/s, loss=0.106, accuracy=0.96]
# val epoch 13: 100%|██████████| 2/2 [00:00<00:00, 157.09it/s, loss=2.03, accuracy=0.38]
# train epoch 14: 100%|██████████| 2/2 [00:00<00:00, 97.42it/s, loss=0.0765, accuracy=0.99]
# val epoch 14: 100%|██████████| 2/2 [00:00<00:00, 204.14it/s, loss=1.94, accuracy=0.41]
# train epoch 15: 100%|██████████| 2/2 [00:00<00:00, 109.10it/s, loss=0.0633, accuracy=0.99]
# val epoch 15: 100%|██████████| 2/2 [00:00<00:00, 201.05it/s, loss=1.79, accuracy=0.42]
# train epoch 16: 100%|██████████| 2/2 [00:00<00:00, 126.11it/s, loss=0.0301, accuracy=1]
# val epoch 16: 100%|██████████| 2/2 [00:00<00:00, 204.30it/s, loss=1.57, accuracy=0.54]
# train epoch 17: 100%|██████████| 2/2 [00:00<00:00, 123.66it/s, loss=0.0373, accuracy=1]
# val epoch 17: 100%|██████████| 2/2 [00:00<00:00, 177.42it/s, loss=1.36, accuracy=0.61]
# train epoch 18: 100%|██████████| 2/2 [00:00<00:00, 112.50it/s, loss=0.0362, accuracy=1]
# val epoch 18: 100%|██████████| 2/2 [00:00<00:00, 217.86it/s, loss=1.19, accuracy=0.65]
# train epoch 19: 100%|██████████| 2/2 [00:00<00:00, 108.65it/s, loss=0.0284, accuracy=1]
# val epoch 19: 100%|██████████| 2/2 [00:00<00:00, 191.08it/s, loss=1.05, accuracy=0.67]
# train epoch 20: 100%|██████████| 2/2 [00:00<00:00, 111.10it/s, loss=0.0411, accuracy=0.99]
# val epoch 20: 100%|██████████| 2/2 [00:00<00:00, 222.82it/s, loss=0.948, accuracy=0.68]
# train epoch 21: 100%|██████████| 2/2 [00:00<00:00, 108.41it/s, loss=0.0354, accuracy=0.99]
# val epoch 21: 100%|██████████| 2/2 [00:00<00:00, 230.74it/s, loss=0.888, accuracy=0.68]
# train epoch 22: 100%|██████████| 2/2 [00:00<00:00, 85.99it/s, loss=0.0352, accuracy=0.99]
# val epoch 22: 100%|██████████| 2/2 [00:00<00:00, 225.23it/s, loss=0.848, accuracy=0.7]
# train epoch 23: 100%|██████████| 2/2 [00:00<00:00, 91.18it/s, loss=0.018, accuracy=1]
# val epoch 23: 100%|██████████| 2/2 [00:00<00:00, 162.75it/s, loss=0.796, accuracy=0.75]
# train epoch 24: 100%|██████████| 2/2 [00:00<00:00, 107.12it/s, loss=0.0532, accuracy=0.98]
# val epoch 24: 100%|██████████| 2/2 [00:00<00:00, 168.62it/s, loss=0.664, accuracy=0.79]
# train epoch 25: 100%|██████████| 2/2 [00:00<00:00, 113.57it/s, loss=0.0139, accuracy=1]
# val epoch 25: 100%|██████████| 2/2 [00:00<00:00, 156.75it/s, loss=0.569, accuracy=0.82]
# train epoch 26: 100%|██████████| 2/2 [00:00<00:00, 96.05it/s, loss=0.0147, accuracy=1]
# val epoch 26: 100%|██████████| 2/2 [00:00<00:00, 164.52it/s, loss=0.505, accuracy=0.85]
# train epoch 27: 100%|██████████| 2/2 [00:00<00:00, 106.05it/s, loss=0.0149, accuracy=1]
# val epoch 27: 100%|██████████| 2/2 [00:00<00:00, 205.18it/s, loss=0.468, accuracy=0.86]
# train epoch 28: 100%|██████████| 2/2 [00:00<00:00, 108.36it/s, loss=0.021, accuracy=1]
# val epoch 28: 100%|██████████| 2/2 [00:00<00:00, 185.35it/s, loss=0.444, accuracy=0.86]
# train epoch 29: 100%|██████████| 2/2 [00:00<00:00, 108.33it/s, loss=0.0136, accuracy=1]
# val epoch 29: 100%|██████████| 2/2 [00:00<00:00, 214.54it/s, loss=0.434, accuracy=0.87]
# train epoch 30: 100%|██████████| 2/2 [00:00<00:00, 106.55it/s, loss=0.0191, accuracy=1]
# val epoch 30: 100%|██████████| 2/2 [00:00<00:00, 172.50it/s, loss=0.426, accuracy=0.87]
# train epoch 31: 100%|██████████| 2/2 [00:00<00:00, 117.57it/s, loss=0.0208, accuracy=1]
# val epoch 31: 100%|██████████| 2/2 [00:00<00:00, 186.24it/s, loss=0.415, accuracy=0.87]
# train epoch 32: 100%|██████████| 2/2 [00:00<00:00, 121.31it/s, loss=0.00962, accuracy=1]
# val epoch 32: 100%|██████████| 2/2 [00:00<00:00, 196.77it/s, loss=0.401, accuracy=0.88]
# train epoch 33: 100%|██████████| 2/2 [00:00<00:00, 110.83it/s, loss=0.0222, accuracy=1]
# val epoch 33: 100%|██████████| 2/2 [00:00<00:00, 176.88it/s, loss=0.377, accuracy=0.87]
# train epoch 34: 100%|██████████| 2/2 [00:00<00:00, 130.59it/s, loss=0.00891, accuracy=1]
# val epoch 34: 100%|██████████| 2/2 [00:00<00:00, 205.29it/s, loss=0.358, accuracy=0.9]
# train epoch 35: 100%|██████████| 2/2 [00:00<00:00, 106.97it/s, loss=0.00998, accuracy=1]
# val epoch 35: 100%|██████████| 2/2 [00:00<00:00, 134.16it/s, loss=0.347, accuracy=0.9]
# train epoch 36: 100%|██████████| 2/2 [00:00<00:00, 89.38it/s, loss=0.0143, accuracy=1]
# val epoch 36: 100%|██████████| 2/2 [00:00<00:00, 141.67it/s, loss=0.328, accuracy=0.91]
# train epoch 37: 100%|██████████| 2/2 [00:00<00:00, 86.92it/s, loss=0.00843, accuracy=1]
# val epoch 37: 100%|██████████| 2/2 [00:00<00:00, 155.24it/s, loss=0.316, accuracy=0.92]
# train epoch 38: 100%|██████████| 2/2 [00:00<00:00, 71.39it/s, loss=0.0109, accuracy=1]
# val epoch 38: 100%|██████████| 2/2 [00:00<00:00, 121.15it/s, loss=0.308, accuracy=0.92]
# train epoch 39: 100%|██████████| 2/2 [00:00<00:00, 73.91it/s, loss=0.0081, accuracy=1]
# val epoch 39: 100%|██████████| 2/2 [00:00<00:00, 114.40it/s, loss=0.304, accuracy=0.92]
# train epoch 40: 100%|██████████| 2/2 [00:00<00:00, 69.21it/s, loss=0.00933, accuracy=1]
# val epoch 40: 100%|██████████| 2/2 [00:00<00:00, 122.91it/s, loss=0.3, accuracy=0.93]
# train epoch 41: 100%|██████████| 2/2 [00:00<00:00, 80.78it/s, loss=0.0144, accuracy=1]
# val epoch 41: 100%|██████████| 2/2 [00:00<00:00, 136.56it/s, loss=0.297, accuracy=0.93]
# train epoch 42: 100%|██████████| 2/2 [00:00<00:00, 77.55it/s, loss=0.00455, accuracy=1]
# val epoch 42: 100%|██████████| 2/2 [00:00<00:00, 158.46it/s, loss=0.299, accuracy=0.92]
# train epoch 43: 100%|██████████| 2/2 [00:00<00:00, 90.55it/s, loss=0.0131, accuracy=1]
# val epoch 43: 100%|██████████| 2/2 [00:00<00:00, 158.49it/s, loss=0.304, accuracy=0.91]
# train epoch 44: 100%|██████████| 2/2 [00:00<00:00, 89.99it/s, loss=0.00557, accuracy=1]
# val epoch 44: 100%|██████████| 2/2 [00:00<00:00, 158.59it/s, loss=0.31, accuracy=0.91]
# train epoch 45: 100%|██████████| 2/2 [00:00<00:00, 83.09it/s, loss=0.00706, accuracy=1]
# val epoch 45: 100%|██████████| 2/2 [00:00<00:00, 132.23it/s, loss=0.319, accuracy=0.9]
# train epoch 46: 100%|██████████| 2/2 [00:00<00:00, 68.35it/s, loss=0.00576, accuracy=1]
# val epoch 46: 100%|██████████| 2/2 [00:00<00:00, 145.42it/s, loss=0.332, accuracy=0.91]
# train epoch 47: 100%|██████████| 2/2 [00:00<00:00, 77.11it/s, loss=0.00527, accuracy=1]
# val epoch 47: 100%|██████████| 2/2 [00:00<00:00, 128.82it/s, loss=0.344, accuracy=0.9]
# train epoch 48: 100%|██████████| 2/2 [00:00<00:00, 73.52it/s, loss=0.00576, accuracy=1]
# val epoch 48: 100%|██████████| 2/2 [00:00<00:00, 152.05it/s, loss=0.355, accuracy=0.9]
# train epoch 49: 100%|██████████| 2/2 [00:00<00:00, 78.31it/s, loss=0.00569, accuracy=1]
# val epoch 49: 100%|██████████| 2/2 [00:00<00:00, 136.25it/s, loss=0.363, accuracy=0.89]
# train epoch 50: 100%|██████████| 2/2 [00:00<00:00, 76.66it/s, loss=0.00433, accuracy=1]
# val epoch 50: 100%|██████████| 2/2 [00:00<00:00, 134.17it/s, loss=0.368, accuracy=0.89]
# train epoch 51: 100%|██████████| 2/2 [00:00<00:00, 72.62it/s, loss=0.00366, accuracy=1]
# val epoch 51: 100%|██████████| 2/2 [00:00<00:00, 139.73it/s, loss=0.369, accuracy=0.89]
# train epoch 52: 100%|██████████| 2/2 [00:00<00:00, 75.15it/s, loss=0.00441, accuracy=1]
# val epoch 52: 100%|██████████| 2/2 [00:00<00:00, 146.12it/s, loss=0.367, accuracy=0.89]
# train epoch 53: 100%|██████████| 2/2 [00:00<00:00, 79.69it/s, loss=0.00825, accuracy=1]
# val epoch 53: 100%|██████████| 2/2 [00:00<00:00, 140.02it/s, loss=0.364, accuracy=0.89]
# train epoch 54: 100%|██████████| 2/2 [00:00<00:00, 90.24it/s, loss=0.00428, accuracy=1]
# val epoch 54: 100%|██████████| 2/2 [00:00<00:00, 161.75it/s, loss=0.356, accuracy=0.89]
# train epoch 55: 100%|██████████| 2/2 [00:00<00:00, 89.46it/s, loss=0.00281, accuracy=1]
# val epoch 55: 100%|██████████| 2/2 [00:00<00:00, 142.24it/s, loss=0.349, accuracy=0.89]
# train epoch 56: 100%|██████████| 2/2 [00:00<00:00, 86.78it/s, loss=0.00431, accuracy=1]
# val epoch 56: 100%|██████████| 2/2 [00:00<00:00, 153.57it/s, loss=0.341, accuracy=0.91]
# train epoch 57: 100%|██████████| 2/2 [00:00<00:00, 83.64it/s, loss=0.00391, accuracy=1]
# val epoch 57: 100%|██████████| 2/2 [00:00<00:00, 181.91it/s, loss=0.335, accuracy=0.9]
# train epoch 58: 100%|██████████| 2/2 [00:00<00:00, 77.94it/s, loss=0.0048, accuracy=1]
# val epoch 58: 100%|██████████| 2/2 [00:00<00:00, 158.46it/s, loss=0.332, accuracy=0.9]
# train epoch 59: 100%|██████████| 2/2 [00:00<00:00, 90.01it/s, loss=0.00467, accuracy=1]
# val epoch 59: 100%|██████████| 2/2 [00:00<00:00, 153.51it/s, loss=0.33, accuracy=0.9]
# train epoch 60: 100%|██████████| 2/2 [00:00<00:00, 93.90it/s, loss=0.00324, accuracy=1]
# val epoch 60: 100%|██████████| 2/2 [00:00<00:00, 145.80it/s, loss=0.328, accuracy=0.91]
# train epoch 61: 100%|██████████| 2/2 [00:00<00:00, 95.35it/s, loss=0.0195, accuracy=0.99]
# val epoch 61: 100%|██████████| 2/2 [00:00<00:00, 123.71it/s, loss=0.326, accuracy=0.91]
# train epoch 62: 100%|██████████| 2/2 [00:00<00:00, 89.24it/s, loss=0.00357, accuracy=1]
# val epoch 62: 100%|██████████| 2/2 [00:00<00:00, 158.88it/s, loss=0.324, accuracy=0.91]
# train epoch 63: 100%|██████████| 2/2 [00:00<00:00, 85.82it/s, loss=0.00333, accuracy=1]
# val epoch 63: 100%|██████████| 2/2 [00:00<00:00, 144.97it/s, loss=0.324, accuracy=0.92]
# train epoch 64: 100%|██████████| 2/2 [00:00<00:00, 76.13it/s, loss=0.00617, accuracy=1]
# val epoch 64: 100%|██████████| 2/2 [00:00<00:00, 127.22it/s, loss=0.325, accuracy=0.92]
# train epoch 65: 100%|██████████| 2/2 [00:00<00:00, 68.75it/s, loss=0.00877, accuracy=1]
# val epoch 65: 100%|██████████| 2/2 [00:00<00:00, 142.94it/s, loss=0.325, accuracy=0.92]
# train epoch 66: 100%|██████████| 2/2 [00:00<00:00, 72.17it/s, loss=0.00703, accuracy=1]
# val epoch 66: 100%|██████████| 2/2 [00:00<00:00, 122.49it/s, loss=0.325, accuracy=0.92]
# train epoch 67: 100%|██████████| 2/2 [00:00<00:00, 70.96it/s, loss=0.00327, accuracy=1]
# val epoch 67: 100%|██████████| 2/2 [00:00<00:00, 129.47it/s, loss=0.327, accuracy=0.92]
# train epoch 68: 100%|██████████| 2/2 [00:00<00:00, 59.44it/s, loss=0.00998, accuracy=1]
# val epoch 68: 100%|██████████| 2/2 [00:00<00:00, 124.47it/s, loss=0.332, accuracy=0.91]
# train epoch 69: 100%|██████████| 2/2 [00:00<00:00, 64.04it/s, loss=0.00304, accuracy=1]
# val epoch 69: 100%|██████████| 2/2 [00:00<00:00, 126.10it/s, loss=0.337, accuracy=0.91]
# train epoch 70: 100%|██████████| 2/2 [00:00<00:00, 73.45it/s, loss=0.00353, accuracy=1]
# val epoch 70: 100%|██████████| 2/2 [00:00<00:00, 127.57it/s, loss=0.343, accuracy=0.9]
# train epoch 71: 100%|██████████| 2/2 [00:00<00:00, 81.44it/s, loss=0.00473, accuracy=1]
# val epoch 71: 100%|██████████| 2/2 [00:00<00:00, 109.24it/s, loss=0.346, accuracy=0.9]
# train epoch 72: 100%|██████████| 2/2 [00:00<00:00, 64.17it/s, loss=0.00393, accuracy=1]
# val epoch 72: 100%|██████████| 2/2 [00:00<00:00, 105.42it/s, loss=0.344, accuracy=0.9]
# train epoch 73: 100%|██████████| 2/2 [00:00<00:00, 52.35it/s, loss=0.00299, accuracy=1]
# val epoch 73: 100%|██████████| 2/2 [00:00<00:00, 115.40it/s, loss=0.343, accuracy=0.9]
# train epoch 74: 100%|██████████| 2/2 [00:00<00:00, 74.65it/s, loss=0.00385, accuracy=1]
# val epoch 74: 100%|██████████| 2/2 [00:00<00:00, 142.31it/s, loss=0.34, accuracy=0.91]
# train epoch 75: 100%|██████████| 2/2 [00:00<00:00, 70.57it/s, loss=0.00464, accuracy=1]
# val epoch 75: 100%|██████████| 2/2 [00:00<00:00, 135.43it/s, loss=0.336, accuracy=0.91]
# train epoch 76: 100%|██████████| 2/2 [00:00<00:00, 70.40it/s, loss=0.00164, accuracy=1]
# val epoch 76: 100%|██████████| 2/2 [00:00<00:00, 119.74it/s, loss=0.337, accuracy=0.9]
# train epoch 77: 100%|██████████| 2/2 [00:00<00:00, 82.42it/s, loss=0.0042, accuracy=1]
# val epoch 77: 100%|██████████| 2/2 [00:00<00:00, 143.38it/s, loss=0.337, accuracy=0.9]
# train epoch 78: 100%|██████████| 2/2 [00:00<00:00, 76.73it/s, loss=0.00202, accuracy=1]
# val epoch 78: 100%|██████████| 2/2 [00:00<00:00, 118.95it/s, loss=0.338, accuracy=0.9]
# train epoch 79: 100%|██████████| 2/2 [00:00<00:00, 71.85it/s, loss=0.00185, accuracy=1]
# val epoch 79: 100%|██████████| 2/2 [00:00<00:00, 134.60it/s, loss=0.341, accuracy=0.9]
# train epoch 80: 100%|██████████| 2/2 [00:00<00:00, 75.49it/s, loss=0.00211, accuracy=1]
# val epoch 80: 100%|██████████| 2/2 [00:00<00:00, 124.26it/s, loss=0.342, accuracy=0.9]
# train epoch 81: 100%|██████████| 2/2 [00:00<00:00, 71.74it/s, loss=0.00232, accuracy=1]
# val epoch 81: 100%|██████████| 2/2 [00:00<00:00, 117.29it/s, loss=0.343, accuracy=0.9]
# train epoch 82: 100%|██████████| 2/2 [00:00<00:00, 71.82it/s, loss=0.00379, accuracy=1]
# val epoch 82: 100%|██████████| 2/2 [00:00<00:00, 113.22it/s, loss=0.342, accuracy=0.9]
# train epoch 83: 100%|██████████| 2/2 [00:00<00:00, 66.18it/s, loss=0.003, accuracy=1]
# val epoch 83: 100%|██████████| 2/2 [00:00<00:00, 135.01it/s, loss=0.34, accuracy=0.9]
# train epoch 84: 100%|██████████| 2/2 [00:00<00:00, 66.95it/s, loss=0.00331, accuracy=1]
# val epoch 84: 100%|██████████| 2/2 [00:00<00:00, 120.35it/s, loss=0.339, accuracy=0.9]
# train epoch 85: 100%|██████████| 2/2 [00:00<00:00, 72.88it/s, loss=0.00214, accuracy=1]
# val epoch 85: 100%|██████████| 2/2 [00:00<00:00, 132.15it/s, loss=0.336, accuracy=0.9]
# train epoch 86: 100%|██████████| 2/2 [00:00<00:00, 72.91it/s, loss=0.00177, accuracy=1]
# val epoch 86: 100%|██████████| 2/2 [00:00<00:00, 106.28it/s, loss=0.335, accuracy=0.91]
# train epoch 87: 100%|██████████| 2/2 [00:00<00:00, 71.74it/s, loss=0.00206, accuracy=1]
# val epoch 87: 100%|██████████| 2/2 [00:00<00:00, 148.57it/s, loss=0.333, accuracy=0.91]
# train epoch 88: 100%|██████████| 2/2 [00:00<00:00, 87.66it/s, loss=0.00313, accuracy=1]
# val epoch 88: 100%|██████████| 2/2 [00:00<00:00, 128.44it/s, loss=0.334, accuracy=0.91]
# train epoch 89: 100%|██████████| 2/2 [00:00<00:00, 63.11it/s, loss=0.00134, accuracy=1]
# val epoch 89: 100%|██████████| 2/2 [00:00<00:00, 115.77it/s, loss=0.335, accuracy=0.9]
# train epoch 90: 100%|██████████| 2/2 [00:00<00:00, 80.58it/s, loss=0.00167, accuracy=1]
# val epoch 90: 100%|██████████| 2/2 [00:00<00:00, 151.07it/s, loss=0.336, accuracy=0.9]
# train epoch 91: 100%|██████████| 2/2 [00:00<00:00, 83.92it/s, loss=0.00309, accuracy=1]
# val epoch 91: 100%|██████████| 2/2 [00:00<00:00, 133.10it/s, loss=0.336, accuracy=0.9]
# train epoch 92: 100%|██████████| 2/2 [00:00<00:00, 74.83it/s, loss=0.00241, accuracy=1]
# val epoch 92: 100%|██████████| 2/2 [00:00<00:00, 163.91it/s, loss=0.337, accuracy=0.9]
# train epoch 93: 100%|██████████| 2/2 [00:00<00:00, 86.64it/s, loss=0.00189, accuracy=1]
# val epoch 93: 100%|██████████| 2/2 [00:00<00:00, 138.47it/s, loss=0.338, accuracy=0.9]
# train epoch 94: 100%|██████████| 2/2 [00:00<00:00, 85.06it/s, loss=0.007, accuracy=1]
# val epoch 94: 100%|██████████| 2/2 [00:00<00:00, 152.67it/s, loss=0.335, accuracy=0.91]
# train epoch 95: 100%|██████████| 2/2 [00:00<00:00, 78.87it/s, loss=0.00285, accuracy=1]
# val epoch 95: 100%|██████████| 2/2 [00:00<00:00, 121.32it/s, loss=0.327, accuracy=0.91]
# train epoch 96: 100%|██████████| 2/2 [00:00<00:00, 87.14it/s, loss=0.00418, accuracy=1]
# val epoch 96: 100%|██████████| 2/2 [00:00<00:00, 130.45it/s, loss=0.32, accuracy=0.91]
# train epoch 97: 100%|██████████| 2/2 [00:00<00:00, 84.12it/s, loss=0.00181, accuracy=1]
# val epoch 97: 100%|██████████| 2/2 [00:00<00:00, 157.94it/s, loss=0.316, accuracy=0.91]
# train epoch 98: 100%|██████████| 2/2 [00:00<00:00, 79.31it/s, loss=0.0017, accuracy=1]
# val epoch 98: 100%|██████████| 2/2 [00:00<00:00, 134.16it/s, loss=0.312, accuracy=0.92]
# train epoch 99: 100%|██████████| 2/2 [00:00<00:00, 80.78it/s, loss=0.00202, accuracy=1]
# val epoch 99: 100%|██████████| 2/2 [00:00<00:00, 118.44it/s, loss=0.31, accuracy=0.92]

# %%
plt.title("Loss")
plt.plot(train_losses, label="train")
plt.plot(val_losses, label="val")
plt.legend()
plt.show()

# %% [markdown]
# We can see that the training loss quickly approaches zero, while the validation loss first decreases, but increases when the network starts to overfit on the training data.

# %%
plt.title("Accuracy")
plt.plot(train_accuracy, label="train")
plt.plot(val_accuracy, label="val")
plt.legend()
plt.show()

# %% [markdown]
# The accuracy on the training data quickly reaches 100%, while the validation accuracy stays at about 80%, slightly decreasing.

# %% [markdown]
# ## Visualizing results

# %% [markdown]
# We can also visualize the predictions of the network on the training set. Note that now we have to use the softmax operation on the model's results, if we want to obtain classification probabilities.

# %%
from torchvision.transforms.functional import to_pil_image

num_test_samples = 25
images, labels = next(Loader(val_data, num_test_samples, transform=val_transform, BATCH_SIZE=num_test_samples))

num_cols = 5
num_rows = int(ceil(num_test_samples/num_cols))
fig, axes = plt.subplots(num_rows, num_cols, figsize=(14, 14))

model.eval()
predictions = model(images.to(device))
scores = nn.functional.softmax(predictions, dim=-1)
predicted_classes = torch.argmax(scores, dim=-1)
# actually if we only need the index of the class with the highest probability, we could omit the softmax operation and perform argmax on the logits directly.
# predicted_classes = torch.argmax(predictions, dim=-1)

for i in range(num_test_samples):
    image, label = images[i], labels[i]
    predicted_class = predicted_classes[i].cpu().item()
    
    # convert the pytorch tensor back to a PIL image
    image = to_pil_image(image)
    
    ax = axes[i//num_cols, i%num_cols]
    ax.imshow(image)
    ax.set_title(f"Prediction: {predicted_class}, gt: {label}", fontdict={"fontsize": 14, "color": ("green" if predicted_class == label else "red")})
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Tasks

# %% [markdown]
# The tasks are now to combat the overfitting with data augmentation, normalization and/or regularization. For each of the following tasks, copy this notebook and rename it according to the task:
# - Modify the `train_transform` to perform a random rotation of the image before passing it to ToTensor. You can use the [RandomRotation](https://pytorch.org/docs/stable/torchvision/transforms.html#torchvision.transforms.RandomRotation) class for this. To combine the rotation transform with the `ToTensor` transform, use the [Compose](https://pytorch.org/docs/stable/torchvision/transforms.html#torchvision.transforms.Compose) class. Make sure to only modify `train_transform` and not `val_transform`, as we do not want to perform random rotations on the validation set.
# - Introduce a weight decay (L2 penalty) of 0.001 by passing a `weight_decay` parameter to the Adam optimizer. See [Adam documentation](https://pytorch.org/docs/stable/optim.html#torch.optim.Adam).
# - Modify the network structure to perform BatchNormalization after each convolution operation. You can use the [BatchNorm2d](https://pytorch.org/docs/stable/nn.html#torch.nn.BatchNorm2d) class for this.
# - Modify the network structure by adding a Dropout layer between the linear layers. Use a dropout probability of 50%. You can use the  [Dropout](https://pytorch.org/docs/stable/nn.html#torch.nn.Dropout) class for this.
#
# In each notebook, adjust the name of the pickle file in the following code:

# %%
import pickle
with open("6_everything.pickle", "wb") as f:
    pickle.dump([train_losses, val_losses], f)

# %% [markdown]
# Then, you can compare the results of the different methods to combat overfitting:

# %%
import glob

plt.figure(figsize=(10, 10))
for f in sorted(glob.glob('*.pickle')):
    with open(f, 'rb') as handle:
        train_losses, val_losses = pickle.load(handle)
    label = " ".join(f.split('.')[0].split('_')[1:])
    plt.plot(train_losses, '--', label=f"{label} (train)")
    plt.plot(val_losses, label=f"{label} (val)")

# plt.yscale('log')
plt.legend()
plt.show()

# %% [markdown]
# You can get the "everything" graph by creating a notebook that combines the changes of all four tasks.

# %% [markdown]
# We can see that all of the above changes decrease the final validation loss. We get the highest reduction when combining all changes, as they all help to combat overfitting and aid generalization.

# %% [markdown]
# ## Bonus tasks

# %% [markdown]
# - In practise, you will often work with custom data formats and thus have to implement custom transforms to perform data augmentation on your data. Creating a custom transform is quite easy. For this task, code the random image rotation transformation in your own custom transform class. You can use the following code to get started:
# ```python
# class MyTransform(object):
#     def __init__(self, arguments):
#         # initialization code here
#         pass
#
#     def __call__(self, sample):
#         # This method gets called on each sample
#         # apply transform to the image
#         # sample is a tuple with (image, label)
#         pass
# ```
# You can use the `.rotate` method of the PIL image to rotate it by a given number of degrees, which you can choose randomly using the `random` module.
# - Instead of using the `weight_decay` parameter of your favorite optimizer, switch out the PyTorch Adam optimizer for an optimizer implementation from the last exercise, and add a L2 penalty to the loss calculation.
# - Switch out the MNIST dataset for the FashionMNIST dataset (also included in torchvision)
# - Remove the limit of 100 samples, and see how your model performs on the full dataset.
