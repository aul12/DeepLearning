# %% [markdown]
# # Exercise 4

# %% [markdown]
# In this exercise, we will work with the MNIST dataset. The dataset contains images of hand-written digits, along with the ground-truth labels (the digit that an image represents).

# %%
from torchvision.datasets import MNIST

# %% [markdown]
# The MNIST dataset is structured into a training set and a validation set, which we can load separately:

# %%
train_data = MNIST('.', download=True, train=True)
val_data = MNIST('.', download=True, train=False)

# %% [markdown]
# We can inspect the structure of the dataset:

# %%
print("len(train_data):", len(train_data))
print("len(val_data):", len(val_data))
print()
first_sample = train_data[0]
print("type(first_sample):", type(first_sample))
print("len(first_sample):", len(first_sample))
print("type(first_sample[0]):", type(first_sample[0]))
print("type(first_sample[1]):", type(first_sample[1]))
print()

image = first_sample[0]
label = first_sample[1]

print("Image size:", image.size)
print("Label:", label)
# Out:
# len(train_data): 60000
# len(val_data): 10000
#
# type(first_sample): <class 'tuple'>
# len(first_sample): 2
# type(first_sample[0]): <class 'PIL.Image.Image'>
# type(first_sample[1]): <class 'int'>
#
# Image size: (28, 28)
# Label: 5

# %% [markdown]
# As we can see, we can load samples from the dataset with the `[]` operator, and each sample is a tuple with an image and the corresponding label.

# %% [markdown]
# ## Plotting the data

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Visualizing the data is always a good idea:

# %%
fig, axes = plt.subplots(5, 5, figsize=(14, 14))
for i in range(25):
    image, label = train_data[i]
    ax = axes[i//5, i%5]
    ax.imshow(image)
    ax.set_title(f"Label: {label}", fontdict={"fontsize": 14})
plt.tight_layout()
plt.show()

# %% [markdown]
# ## LeNet implementation

# %% [markdown]
# We will use a quite simple network to learn digit recognition. The LeNet architecture has just two convolutional layers and two linear layers, along with a couple of nonlinear activations and two pooling layers. The following code implements the network using PyTorch:

# %%
import torch
from torch import nn

class LeNet(nn.Module):
    def __init__(self, num_classes, input_shape):
        super(LeNet, self).__init__()

        # first convolution layer + activation + max pooling
        self.conv1 = nn.Conv2d(input_shape[0], 20, (5, 5))
        self.act1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2)
        self.bn1 = nn.BatchNorm2d(20)
        
        # second convolution layer + activation + max pooling
        self.conv2 = nn.Conv2d(20, 50, (5, 5))
        self.act2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2)
        self.bn2 = nn.BatchNorm2d(50)
        
        # first linear layer + activation
        self.conv_output_len = (50*4*4)
        self.linear1 = nn.Linear(self.conv_output_len, 500)
        self.act3 = nn.ReLU()
        
        # final linear layer to produce the correct number of outputs
        self.linear2 = nn.Linear(500, num_classes)

    def forward(self, x):
        # perform convolution -> activation -> pooling
        x = self.bn1(self.pool1(self.act1(self.conv1(x))))
        x = self.bn2(self.pool2(self.act2(self.conv2(x))))
        
        # flatten the features obtained from the conv layers: (BATCH_SIZE, 50, 4, 4) -> (BATCH_SIZE, 50*4*4)
        batch_size = x.shape[0]
        x = x.view(batch_size, self.conv_output_len)
        
        # final linear layers and activations
        x = self.act3(self.linear1(x))
        x = self.linear2(x)
        
        return x

# %% [markdown]
# Some notable changes from the LeNet implementation in the original paper are the use of ReLU instead of sigmoid/tanh activations, use of Max Pooling instead of Average Pooling and the number of filters / parameters used in the layers (to allow direct application to the MNIST images without upscaling to 32x32 pixels).
#
# Note that the network does not contain a softmax activation on the final layer, as we will use the `cross_entropy` loss function from PyTorch lateron, which works on the raw logits directly, and yields incorrect results when a softmax operation is applied beforehand.

# %% [markdown]
# ## Torchvision version check

# %% [markdown]
# torchvision < 0.6.0 has a bug when using the RandomRotation class (see https://github.com/pytorch/vision/pull/1828), which is required for one of the tasks below. The following code checks if you are using a recent version of torchvision. If it prints out that you should upgrade, make sure to install the latest torchvision with pip or conda (see setup_instructions.pdf from exercise 1)!

# %%
import torchvision
from packaging import version
import logging

print("torchvision version:", torchvision.__version__)
if version.parse(torchvision.__version__) < version.parse('0.6.0a0'):
    logging.error("You seem to be running an old version of torchvision, please upgrade to the latest version!")
else:
    print("torchvision version seems to be fine.")
# Out:
# torchvision version: 0.6.0
# torchvision version seems to be fine.

# %% [markdown]
# ## Training

# %% [markdown]
# The following code implements a training and validation loop. In each epoch, one iteration over the training set is performed, followed by one iteration over the validation set. This allows us to check the training and validation loss and classification accuracy in each epoch, which is useful to spot overfitting.
#
# As the point of this exercise is to show you the effect of overfitting and how to combat it, we use only a very small subset of the training data. This leads to the network quickly overfitting quite heavily on the training data and thus not generalizing.

# %%
from torchvision.transforms import ToTensor, RandomRotation, Compose
from torch.nn.functional import cross_entropy
import numpy as np
import tqdm
from math import ceil
import random

NUM_EPOCHS = 100
BATCH_SIZE = 10
NUM_CLASSES = 10
LR = 0.001

random.seed(0)
torch.manual_seed(0)
model = LeNet(NUM_CLASSES, (1, 28, 28))
device = "cuda" if torch.cuda.is_available() else "cpu"
model.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=LR)

num_train_images = 100 # len(train_data)
num_val_images = 100 # len(val_data)

train_losses = []
val_losses = []
train_accuracy = []
val_accuracy = []

BATCH_SIZE = 50

# This loader generates batches of data according to BATCH_SIZE
# It also applies a `transform` function to the image (see below)
def Loader(data, num_samples, transform, BATCH_SIZE=BATCH_SIZE):
    NUM_BATCHES = int(ceil(num_samples/BATCH_SIZE))
    
    # This generates the batches, one after another
    for i in range(NUM_BATCHES):
        indices = range(i*BATCH_SIZE, min((i+1)*BATCH_SIZE, num_samples))
        batch = [data[i] for i in indices]
        
        # convert PIL image and label to PyTorch tensors
        images = torch.stack([transform(item[0]) for item in batch])
        labels = torch.stack([torch.tensor(item[1]) for item in batch])
        yield images, labels

# Image transforms
# ToTensor converts a PIL image to a PyTorch tensor
# It also swaps the order of the image channels, e.g. (28, 28, 3) to (3, 28, 28)
# Also, the pixel values are normalized to be between 0 and 1 (instead of between 0 and 255)
# See https://pytorch.org/docs/stable/torchvision/transforms.html#torchvision.transforms.ToTensor
train_transform = ToTensor()
val_transform = ToTensor()

for epoch in range(NUM_EPOCHS):
    # perform training followed by validation
    for mode, data, num_samples, transform in [
        ("train", train_data, num_train_images, train_transform),
        ("val", val_data, num_val_images, val_transform)
    ]:
        # progressbar setup
        num_batches = int(ceil(num_samples/BATCH_SIZE))
        pbar = tqdm.tqdm(total=num_batches, desc=f"{mode} epoch {epoch}")

        if mode == "train":
            model.train() # do calculate gradients for training mode
        else:
            model.eval() # do not calculate gradients in validation mode

        # initial values of the metrics (loss, accurracy)
        runningLoss = 0.
        correct_predictions = 0
        # total number of images that were processed
        total_samples = 0
        
        # loop over the data
        for i_batch, batch in enumerate(Loader(data, num_samples, transform)):
            images, labels = batch
            # move tensors to the correct device
            images = images.to(device)
            labels = labels.to(device)

            # run the model
            predictions = model.forward(images)

            # loss calculation
            loss = cross_entropy(predictions, labels)

            # calculate the metrics for the progress bar
            num_batch_samples = len(images)
            runningLoss += loss.item() * num_batch_samples
            correct_predictions += (torch.argmax(predictions, dim=-1) == labels).sum().item()
            total_samples += num_batch_samples
            
            pbar.update(1)
            pbar.set_postfix({
                "loss": runningLoss / total_samples,
                "accuracy": correct_predictions / total_samples
            })

            # weight update
            if mode == "train":
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
        epoch_loss = runningLoss / total_samples
        epoch_accuracy = correct_predictions / total_samples
        if mode == "train":
            train_losses.append(epoch_loss)
            train_accuracy.append(epoch_accuracy)
        else:
            val_losses.append(epoch_loss)
            val_accuracy.append(epoch_accuracy)

        pbar.close()
# Out:
# train epoch 0: 100%|██████████| 2/2 [00:00<00:00, 82.83it/s, loss=2.08, accuracy=0.33]
# val epoch 0: 100%|██████████| 2/2 [00:00<00:00, 170.13it/s, loss=2.25, accuracy=0.52]
# train epoch 1: 100%|██████████| 2/2 [00:00<00:00, 114.47it/s, loss=0.826, accuracy=0.93]
# val epoch 1: 100%|██████████| 2/2 [00:00<00:00, 161.94it/s, loss=2.13, accuracy=0.63]
# train epoch 2: 100%|██████████| 2/2 [00:00<00:00, 122.31it/s, loss=0.311, accuracy=0.99]
# val epoch 2: 100%|██████████| 2/2 [00:00<00:00, 134.48it/s, loss=2.01, accuracy=0.34]
# train epoch 3: 100%|██████████| 2/2 [00:00<00:00, 97.56it/s, loss=0.109, accuracy=1]
# val epoch 3: 100%|██████████| 2/2 [00:00<00:00, 126.55it/s, loss=1.92, accuracy=0.27]
# train epoch 4: 100%|██████████| 2/2 [00:00<00:00, 95.56it/s, loss=0.0383, accuracy=1]
# val epoch 4: 100%|██████████| 2/2 [00:00<00:00, 181.93it/s, loss=1.9, accuracy=0.21]
# train epoch 5: 100%|██████████| 2/2 [00:00<00:00, 149.53it/s, loss=0.0154, accuracy=1]
# val epoch 5: 100%|██████████| 2/2 [00:00<00:00, 144.10it/s, loss=1.95, accuracy=0.2]
# train epoch 6: 100%|██████████| 2/2 [00:00<00:00, 106.61it/s, loss=0.00725, accuracy=1]
# val epoch 6: 100%|██████████| 2/2 [00:00<00:00, 199.50it/s, loss=2.05, accuracy=0.23]
# train epoch 7: 100%|██████████| 2/2 [00:00<00:00, 135.92it/s, loss=0.00381, accuracy=1]
# val epoch 7: 100%|██████████| 2/2 [00:00<00:00, 150.00it/s, loss=2.15, accuracy=0.24]
# train epoch 8: 100%|██████████| 2/2 [00:00<00:00, 142.41it/s, loss=0.00219, accuracy=1]
# val epoch 8: 100%|██████████| 2/2 [00:00<00:00, 205.90it/s, loss=2.24, accuracy=0.27]
# train epoch 9: 100%|██████████| 2/2 [00:00<00:00, 115.10it/s, loss=0.00135, accuracy=1]
# val epoch 9: 100%|██████████| 2/2 [00:00<00:00, 169.76it/s, loss=2.27, accuracy=0.28]
# train epoch 10: 100%|██████████| 2/2 [00:00<00:00, 127.46it/s, loss=0.000895, accuracy=1]
# val epoch 10: 100%|██████████| 2/2 [00:00<00:00, 163.79it/s, loss=2.26, accuracy=0.31]
# train epoch 11: 100%|██████████| 2/2 [00:00<00:00, 135.04it/s, loss=0.000631, accuracy=1]
# val epoch 11: 100%|██████████| 2/2 [00:00<00:00, 229.57it/s, loss=2.2, accuracy=0.37]
# train epoch 12: 100%|██████████| 2/2 [00:00<00:00, 128.20it/s, loss=0.00047, accuracy=1]
# val epoch 12: 100%|██████████| 2/2 [00:00<00:00, 184.01it/s, loss=2.09, accuracy=0.4]
# train epoch 13: 100%|██████████| 2/2 [00:00<00:00, 117.43it/s, loss=0.000366, accuracy=1]
# val epoch 13: 100%|██████████| 2/2 [00:00<00:00, 162.35it/s, loss=1.95, accuracy=0.43]
# train epoch 14: 100%|██████████| 2/2 [00:00<00:00, 117.48it/s, loss=0.000296, accuracy=1]
# val epoch 14: 100%|██████████| 2/2 [00:00<00:00, 169.17it/s, loss=1.79, accuracy=0.49]
# train epoch 15: 100%|██████████| 2/2 [00:00<00:00, 131.50it/s, loss=0.000248, accuracy=1]
# val epoch 15: 100%|██████████| 2/2 [00:00<00:00, 218.30it/s, loss=1.62, accuracy=0.52]
# train epoch 16: 100%|██████████| 2/2 [00:00<00:00, 113.49it/s, loss=0.000213, accuracy=1]
# val epoch 16: 100%|██████████| 2/2 [00:00<00:00, 232.68it/s, loss=1.44, accuracy=0.57]
# train epoch 17: 100%|██████████| 2/2 [00:00<00:00, 138.53it/s, loss=0.000187, accuracy=1]
# val epoch 17: 100%|██████████| 2/2 [00:00<00:00, 183.70it/s, loss=1.28, accuracy=0.64]
# train epoch 18: 100%|██████████| 2/2 [00:00<00:00, 129.00it/s, loss=0.000167, accuracy=1]
# val epoch 18: 100%|██████████| 2/2 [00:00<00:00, 221.09it/s, loss=1.14, accuracy=0.66]
# train epoch 19: 100%|██████████| 2/2 [00:00<00:00, 117.65it/s, loss=0.000152, accuracy=1]
# val epoch 19: 100%|██████████| 2/2 [00:00<00:00, 207.81it/s, loss=1.01, accuracy=0.67]
# train epoch 20: 100%|██████████| 2/2 [00:00<00:00, 150.35it/s, loss=0.00014, accuracy=1]
# val epoch 20: 100%|██████████| 2/2 [00:00<00:00, 216.67it/s, loss=0.914, accuracy=0.71]
# train epoch 21: 100%|██████████| 2/2 [00:00<00:00, 136.46it/s, loss=0.00013, accuracy=1]
# val epoch 21: 100%|██████████| 2/2 [00:00<00:00, 177.26it/s, loss=0.834, accuracy=0.74]
# train epoch 22: 100%|██████████| 2/2 [00:00<00:00, 142.11it/s, loss=0.000122, accuracy=1]
# val epoch 22: 100%|██████████| 2/2 [00:00<00:00, 158.90it/s, loss=0.771, accuracy=0.74]
# train epoch 23: 100%|██████████| 2/2 [00:00<00:00, 130.07it/s, loss=0.000115, accuracy=1]
# val epoch 23: 100%|██████████| 2/2 [00:00<00:00, 193.06it/s, loss=0.721, accuracy=0.76]
# train epoch 24: 100%|██████████| 2/2 [00:00<00:00, 130.38it/s, loss=0.00011, accuracy=1]
# val epoch 24: 100%|██████████| 2/2 [00:00<00:00, 177.17it/s, loss=0.682, accuracy=0.76]
# train epoch 25: 100%|██████████| 2/2 [00:00<00:00, 146.94it/s, loss=0.000105, accuracy=1]
# val epoch 25: 100%|██████████| 2/2 [00:00<00:00, 228.32it/s, loss=0.653, accuracy=0.76]
# train epoch 26: 100%|██████████| 2/2 [00:00<00:00, 129.81it/s, loss=0.000101, accuracy=1]
# val epoch 26: 100%|██████████| 2/2 [00:00<00:00, 171.54it/s, loss=0.632, accuracy=0.77]
# train epoch 27: 100%|██████████| 2/2 [00:00<00:00, 136.48it/s, loss=9.76e-5, accuracy=1]
# val epoch 27: 100%|██████████| 2/2 [00:00<00:00, 157.05it/s, loss=0.616, accuracy=0.79]
# train epoch 28: 100%|██████████| 2/2 [00:00<00:00, 117.12it/s, loss=9.46e-5, accuracy=1]
# val epoch 28: 100%|██████████| 2/2 [00:00<00:00, 160.73it/s, loss=0.605, accuracy=0.8]
# train epoch 29: 100%|██████████| 2/2 [00:00<00:00, 142.58it/s, loss=9.2e-5, accuracy=1]
# val epoch 29: 100%|██████████| 2/2 [00:00<00:00, 193.69it/s, loss=0.598, accuracy=0.81]
# train epoch 30: 100%|██████████| 2/2 [00:00<00:00, 110.81it/s, loss=8.96e-5, accuracy=1]
# val epoch 30: 100%|██████████| 2/2 [00:00<00:00, 178.86it/s, loss=0.592, accuracy=0.81]
# train epoch 31: 100%|██████████| 2/2 [00:00<00:00, 141.61it/s, loss=8.75e-5, accuracy=1]
# val epoch 31: 100%|██████████| 2/2 [00:00<00:00, 160.37it/s, loss=0.589, accuracy=0.82]
# train epoch 32: 100%|██████████| 2/2 [00:00<00:00, 115.23it/s, loss=8.55e-5, accuracy=1]
# val epoch 32: 100%|██████████| 2/2 [00:00<00:00, 231.86it/s, loss=0.587, accuracy=0.82]
# train epoch 33: 100%|██████████| 2/2 [00:00<00:00, 148.61it/s, loss=8.38e-5, accuracy=1]
# val epoch 33: 100%|██████████| 2/2 [00:00<00:00, 170.18it/s, loss=0.586, accuracy=0.82]
# train epoch 34: 100%|██████████| 2/2 [00:00<00:00, 99.36it/s, loss=8.22e-5, accuracy=1]
# val epoch 34: 100%|██████████| 2/2 [00:00<00:00, 207.55it/s, loss=0.586, accuracy=0.82]
# train epoch 35: 100%|██████████| 2/2 [00:00<00:00, 126.66it/s, loss=8.07e-5, accuracy=1]
# val epoch 35: 100%|██████████| 2/2 [00:00<00:00, 166.98it/s, loss=0.585, accuracy=0.82]
# train epoch 36: 100%|██████████| 2/2 [00:00<00:00, 132.77it/s, loss=7.93e-5, accuracy=1]
# val epoch 36: 100%|██████████| 2/2 [00:00<00:00, 153.06it/s, loss=0.585, accuracy=0.82]
# train epoch 37: 100%|██████████| 2/2 [00:00<00:00, 107.35it/s, loss=7.8e-5, accuracy=1]
# val epoch 37: 100%|██████████| 2/2 [00:00<00:00, 190.38it/s, loss=0.585, accuracy=0.82]
# train epoch 38: 100%|██████████| 2/2 [00:00<00:00, 134.67it/s, loss=7.68e-5, accuracy=1]
# val epoch 38: 100%|██████████| 2/2 [00:00<00:00, 151.62it/s, loss=0.584, accuracy=0.82]
# train epoch 39: 100%|██████████| 2/2 [00:00<00:00, 129.53it/s, loss=7.57e-5, accuracy=1]
# val epoch 39: 100%|██████████| 2/2 [00:00<00:00, 194.58it/s, loss=0.584, accuracy=0.82]
# train epoch 40: 100%|██████████| 2/2 [00:00<00:00, 129.13it/s, loss=7.47e-5, accuracy=1]
# val epoch 40: 100%|██████████| 2/2 [00:00<00:00, 185.49it/s, loss=0.584, accuracy=0.82]
# train epoch 41: 100%|██████████| 2/2 [00:00<00:00, 128.37it/s, loss=7.37e-5, accuracy=1]
# val epoch 41: 100%|██████████| 2/2 [00:00<00:00, 191.33it/s, loss=0.584, accuracy=0.82]
# train epoch 42: 100%|██████████| 2/2 [00:00<00:00, 133.77it/s, loss=7.26e-5, accuracy=1]
# val epoch 42: 100%|██████████| 2/2 [00:00<00:00, 150.65it/s, loss=0.584, accuracy=0.82]
# train epoch 43: 100%|██████████| 2/2 [00:00<00:00, 129.20it/s, loss=7.18e-5, accuracy=1]
# val epoch 43: 100%|██████████| 2/2 [00:00<00:00, 159.90it/s, loss=0.584, accuracy=0.82]
# train epoch 44: 100%|██████████| 2/2 [00:00<00:00, 134.50it/s, loss=7.08e-5, accuracy=1]
# val epoch 44: 100%|██████████| 2/2 [00:00<00:00, 224.93it/s, loss=0.584, accuracy=0.82]
# train epoch 45: 100%|██████████| 2/2 [00:00<00:00, 110.83it/s, loss=6.99e-5, accuracy=1]
# val epoch 45: 100%|██████████| 2/2 [00:00<00:00, 146.02it/s, loss=0.584, accuracy=0.82]
# train epoch 46: 100%|██████████| 2/2 [00:00<00:00, 116.82it/s, loss=6.91e-5, accuracy=1]
# val epoch 46: 100%|██████████| 2/2 [00:00<00:00, 179.03it/s, loss=0.584, accuracy=0.82]
# train epoch 47: 100%|██████████| 2/2 [00:00<00:00, 141.95it/s, loss=6.83e-5, accuracy=1]
# val epoch 47: 100%|██████████| 2/2 [00:00<00:00, 212.50it/s, loss=0.584, accuracy=0.82]
# train epoch 48: 100%|██████████| 2/2 [00:00<00:00, 106.51it/s, loss=6.75e-5, accuracy=1]
# val epoch 48: 100%|██████████| 2/2 [00:00<00:00, 207.43it/s, loss=0.584, accuracy=0.82]
# train epoch 49: 100%|██████████| 2/2 [00:00<00:00, 116.97it/s, loss=6.67e-5, accuracy=1]
# val epoch 49: 100%|██████████| 2/2 [00:00<00:00, 221.27it/s, loss=0.584, accuracy=0.82]
# train epoch 50: 100%|██████████| 2/2 [00:00<00:00, 127.49it/s, loss=6.59e-5, accuracy=1]
# val epoch 50: 100%|██████████| 2/2 [00:00<00:00, 176.10it/s, loss=0.583, accuracy=0.82]
# train epoch 51: 100%|██████████| 2/2 [00:00<00:00, 112.87it/s, loss=6.52e-5, accuracy=1]
# val epoch 51: 100%|██████████| 2/2 [00:00<00:00, 184.35it/s, loss=0.583, accuracy=0.82]
# train epoch 52: 100%|██████████| 2/2 [00:00<00:00, 134.26it/s, loss=6.45e-5, accuracy=1]
# val epoch 52: 100%|██████████| 2/2 [00:00<00:00, 211.45it/s, loss=0.584, accuracy=0.82]
# train epoch 53: 100%|██████████| 2/2 [00:00<00:00, 112.08it/s, loss=6.38e-5, accuracy=1]
# val epoch 53: 100%|██████████| 2/2 [00:00<00:00, 223.88it/s, loss=0.584, accuracy=0.82]
# train epoch 54: 100%|██████████| 2/2 [00:00<00:00, 119.16it/s, loss=6.31e-5, accuracy=1]
# val epoch 54: 100%|██████████| 2/2 [00:00<00:00, 181.00it/s, loss=0.584, accuracy=0.82]
# train epoch 55: 100%|██████████| 2/2 [00:00<00:00, 136.73it/s, loss=6.24e-5, accuracy=1]
# val epoch 55: 100%|██████████| 2/2 [00:00<00:00, 165.36it/s, loss=0.584, accuracy=0.82]
# train epoch 56: 100%|██████████| 2/2 [00:00<00:00, 124.72it/s, loss=6.18e-5, accuracy=1]
# val epoch 56: 100%|██████████| 2/2 [00:00<00:00, 160.66it/s, loss=0.584, accuracy=0.82]
# train epoch 57: 100%|██████████| 2/2 [00:00<00:00, 122.56it/s, loss=6.11e-5, accuracy=1]
# val epoch 57: 100%|██████████| 2/2 [00:00<00:00, 170.36it/s, loss=0.584, accuracy=0.82]
# train epoch 58: 100%|██████████| 2/2 [00:00<00:00, 135.92it/s, loss=6.05e-5, accuracy=1]
# val epoch 58: 100%|██████████| 2/2 [00:00<00:00, 199.31it/s, loss=0.584, accuracy=0.82]
# train epoch 59: 100%|██████████| 2/2 [00:00<00:00, 100.73it/s, loss=5.99e-5, accuracy=1]
# val epoch 59: 100%|██████████| 2/2 [00:00<00:00, 225.73it/s, loss=0.584, accuracy=0.82]
# train epoch 60: 100%|██████████| 2/2 [00:00<00:00, 140.65it/s, loss=5.93e-5, accuracy=1]
# val epoch 60: 100%|██████████| 2/2 [00:00<00:00, 166.91it/s, loss=0.584, accuracy=0.82]
# train epoch 61: 100%|██████████| 2/2 [00:00<00:00, 134.34it/s, loss=5.87e-5, accuracy=1]
# val epoch 61: 100%|██████████| 2/2 [00:00<00:00, 145.63it/s, loss=0.584, accuracy=0.82]
# train epoch 62: 100%|██████████| 2/2 [00:00<00:00, 106.90it/s, loss=5.81e-5, accuracy=1]
# val epoch 62: 100%|██████████| 2/2 [00:00<00:00, 176.04it/s, loss=0.584, accuracy=0.82]
# train epoch 63: 100%|██████████| 2/2 [00:00<00:00, 101.66it/s, loss=5.75e-5, accuracy=1]
# val epoch 63: 100%|██████████| 2/2 [00:00<00:00, 159.79it/s, loss=0.584, accuracy=0.82]
# train epoch 64: 100%|██████████| 2/2 [00:00<00:00, 86.73it/s, loss=5.69e-5, accuracy=1]
# val epoch 64: 100%|██████████| 2/2 [00:00<00:00, 144.44it/s, loss=0.584, accuracy=0.82]
# train epoch 65: 100%|██████████| 2/2 [00:00<00:00, 103.76it/s, loss=5.64e-5, accuracy=1]
# val epoch 65: 100%|██████████| 2/2 [00:00<00:00, 170.94it/s, loss=0.584, accuracy=0.82]
# train epoch 66: 100%|██████████| 2/2 [00:00<00:00, 110.73it/s, loss=5.58e-5, accuracy=1]
# val epoch 66: 100%|██████████| 2/2 [00:00<00:00, 163.10it/s, loss=0.584, accuracy=0.82]
# train epoch 67: 100%|██████████| 2/2 [00:00<00:00, 107.93it/s, loss=5.53e-5, accuracy=1]
# val epoch 67: 100%|██████████| 2/2 [00:00<00:00, 138.71it/s, loss=0.584, accuracy=0.82]
# train epoch 68: 100%|██████████| 2/2 [00:00<00:00, 92.16it/s, loss=5.48e-5, accuracy=1]
# val epoch 68: 100%|██████████| 2/2 [00:00<00:00, 154.32it/s, loss=0.584, accuracy=0.82]
# train epoch 69: 100%|██████████| 2/2 [00:00<00:00, 100.10it/s, loss=5.43e-5, accuracy=1]
# val epoch 69: 100%|██████████| 2/2 [00:00<00:00, 154.46it/s, loss=0.584, accuracy=0.82]
# train epoch 70: 100%|██████████| 2/2 [00:00<00:00, 116.21it/s, loss=5.37e-5, accuracy=1]
# val epoch 70: 100%|██████████| 2/2 [00:00<00:00, 149.97it/s, loss=0.584, accuracy=0.82]
# train epoch 71: 100%|██████████| 2/2 [00:00<00:00, 111.61it/s, loss=5.32e-5, accuracy=1]
# val epoch 71: 100%|██████████| 2/2 [00:00<00:00, 163.53it/s, loss=0.584, accuracy=0.82]
# train epoch 72: 100%|██████████| 2/2 [00:00<00:00, 109.49it/s, loss=5.28e-5, accuracy=1]
# val epoch 72: 100%|██████████| 2/2 [00:00<00:00, 164.73it/s, loss=0.584, accuracy=0.82]
# train epoch 73: 100%|██████████| 2/2 [00:00<00:00, 98.77it/s, loss=5.23e-5, accuracy=1]
# val epoch 73: 100%|██████████| 2/2 [00:00<00:00, 149.99it/s, loss=0.584, accuracy=0.82]
# train epoch 74: 100%|██████████| 2/2 [00:00<00:00, 115.98it/s, loss=5.18e-5, accuracy=1]
# val epoch 74: 100%|██████████| 2/2 [00:00<00:00, 156.74it/s, loss=0.584, accuracy=0.82]
# train epoch 75: 100%|██████████| 2/2 [00:00<00:00, 112.90it/s, loss=5.13e-5, accuracy=1]
# val epoch 75: 100%|██████████| 2/2 [00:00<00:00, 168.77it/s, loss=0.585, accuracy=0.82]
# train epoch 76: 100%|██████████| 2/2 [00:00<00:00, 93.52it/s, loss=5.09e-5, accuracy=1]
# val epoch 76: 100%|██████████| 2/2 [00:00<00:00, 167.50it/s, loss=0.585, accuracy=0.82]
# train epoch 77: 100%|██████████| 2/2 [00:00<00:00, 110.34it/s, loss=5.04e-5, accuracy=1]
# val epoch 77: 100%|██████████| 2/2 [00:00<00:00, 156.71it/s, loss=0.585, accuracy=0.82]
# train epoch 78: 100%|██████████| 2/2 [00:00<00:00, 103.04it/s, loss=4.99e-5, accuracy=1]
# val epoch 78: 100%|██████████| 2/2 [00:00<00:00, 126.72it/s, loss=0.585, accuracy=0.82]
# train epoch 79: 100%|██████████| 2/2 [00:00<00:00, 104.88it/s, loss=4.95e-5, accuracy=1]
# val epoch 79: 100%|██████████| 2/2 [00:00<00:00, 122.89it/s, loss=0.585, accuracy=0.82]
# train epoch 80: 100%|██████████| 2/2 [00:00<00:00, 78.76it/s, loss=4.91e-5, accuracy=1]
# val epoch 80: 100%|██████████| 2/2 [00:00<00:00, 144.03it/s, loss=0.585, accuracy=0.82]
# train epoch 81: 100%|██████████| 2/2 [00:00<00:00, 97.80it/s, loss=4.86e-5, accuracy=1]
# val epoch 81: 100%|██████████| 2/2 [00:00<00:00, 114.51it/s, loss=0.585, accuracy=0.82]
# train epoch 82: 100%|██████████| 2/2 [00:00<00:00, 95.36it/s, loss=4.82e-5, accuracy=1]
# val epoch 82: 100%|██████████| 2/2 [00:00<00:00, 145.24it/s, loss=0.585, accuracy=0.82]
# train epoch 83: 100%|██████████| 2/2 [00:00<00:00, 105.36it/s, loss=4.78e-5, accuracy=1]
# val epoch 83: 100%|██████████| 2/2 [00:00<00:00, 151.39it/s, loss=0.585, accuracy=0.82]
# train epoch 84: 100%|██████████| 2/2 [00:00<00:00, 105.07it/s, loss=4.73e-5, accuracy=1]
# val epoch 84: 100%|██████████| 2/2 [00:00<00:00, 156.46it/s, loss=0.585, accuracy=0.82]
# train epoch 85: 100%|██████████| 2/2 [00:00<00:00, 109.01it/s, loss=4.69e-5, accuracy=1]
# val epoch 85: 100%|██████████| 2/2 [00:00<00:00, 149.05it/s, loss=0.585, accuracy=0.82]
# train epoch 86: 100%|██████████| 2/2 [00:00<00:00, 92.87it/s, loss=4.66e-5, accuracy=1]
# val epoch 86: 100%|██████████| 2/2 [00:00<00:00, 157.91it/s, loss=0.585, accuracy=0.82]
# train epoch 87: 100%|██████████| 2/2 [00:00<00:00, 104.92it/s, loss=4.62e-5, accuracy=1]
# val epoch 87: 100%|██████████| 2/2 [00:00<00:00, 125.53it/s, loss=0.585, accuracy=0.82]
# train epoch 88: 100%|██████████| 2/2 [00:00<00:00, 101.56it/s, loss=4.58e-5, accuracy=1]
# val epoch 88: 100%|██████████| 2/2 [00:00<00:00, 157.78it/s, loss=0.585, accuracy=0.82]
# train epoch 89: 100%|██████████| 2/2 [00:00<00:00, 95.31it/s, loss=4.54e-5, accuracy=1]
# val epoch 89: 100%|██████████| 2/2 [00:00<00:00, 113.13it/s, loss=0.586, accuracy=0.82]
# train epoch 90: 100%|██████████| 2/2 [00:00<00:00, 101.93it/s, loss=4.5e-5, accuracy=1]
# val epoch 90: 100%|██████████| 2/2 [00:00<00:00, 120.61it/s, loss=0.586, accuracy=0.82]
# train epoch 91: 100%|██████████| 2/2 [00:00<00:00, 94.43it/s, loss=4.47e-5, accuracy=1]
# val epoch 91: 100%|██████████| 2/2 [00:00<00:00, 127.98it/s, loss=0.586, accuracy=0.82]
# train epoch 92: 100%|██████████| 2/2 [00:00<00:00, 91.56it/s, loss=4.43e-5, accuracy=1]
# val epoch 92: 100%|██████████| 2/2 [00:00<00:00, 123.07it/s, loss=0.586, accuracy=0.82]
# train epoch 93: 100%|██████████| 2/2 [00:00<00:00, 105.27it/s, loss=4.39e-5, accuracy=1]
# val epoch 93: 100%|██████████| 2/2 [00:00<00:00, 140.49it/s, loss=0.586, accuracy=0.82]
# train epoch 94: 100%|██████████| 2/2 [00:00<00:00, 89.72it/s, loss=4.36e-5, accuracy=1]
# val epoch 94: 100%|██████████| 2/2 [00:00<00:00, 147.88it/s, loss=0.586, accuracy=0.82]
# train epoch 95: 100%|██████████| 2/2 [00:00<00:00, 99.74it/s, loss=4.32e-5, accuracy=1]
# val epoch 95: 100%|██████████| 2/2 [00:00<00:00, 130.53it/s, loss=0.586, accuracy=0.82]
# train epoch 96: 100%|██████████| 2/2 [00:00<00:00, 103.86it/s, loss=4.28e-5, accuracy=1]
# val epoch 96: 100%|██████████| 2/2 [00:00<00:00, 130.14it/s, loss=0.586, accuracy=0.82]
# train epoch 97: 100%|██████████| 2/2 [00:00<00:00, 117.37it/s, loss=4.25e-5, accuracy=1]
# val epoch 97: 100%|██████████| 2/2 [00:00<00:00, 139.80it/s, loss=0.586, accuracy=0.82]
# train epoch 98: 100%|██████████| 2/2 [00:00<00:00, 111.07it/s, loss=4.22e-5, accuracy=1]
# val epoch 98: 100%|██████████| 2/2 [00:00<00:00, 131.38it/s, loss=0.586, accuracy=0.82]
# train epoch 99: 100%|██████████| 2/2 [00:00<00:00, 111.18it/s, loss=4.18e-5, accuracy=1]
# val epoch 99: 100%|██████████| 2/2 [00:00<00:00, 152.97it/s, loss=0.586, accuracy=0.82]

# %%
plt.title("Loss")
plt.plot(train_losses, label="train")
plt.plot(val_losses, label="val")
plt.legend()
plt.show()

# %% [markdown]
# We can see that the training loss quickly approaches zero, while the validation loss first decreases, but increases when the network starts to overfit on the training data.

# %%
plt.title("Accuracy")
plt.plot(train_accuracy, label="train")
plt.plot(val_accuracy, label="val")
plt.legend()
plt.show()

# %% [markdown]
# The accuracy on the training data quickly reaches 100%, while the validation accuracy stays at about 80%, slightly decreasing.

# %% [markdown]
# ## Visualizing results

# %% [markdown]
# We can also visualize the predictions of the network on the training set. Note that now we have to use the softmax operation on the model's results, if we want to obtain classification probabilities.

# %%
from torchvision.transforms.functional import to_pil_image

num_test_samples = 25
images, labels = next(Loader(val_data, num_test_samples, transform=val_transform, BATCH_SIZE=num_test_samples))

num_cols = 5
num_rows = int(ceil(num_test_samples/num_cols))
fig, axes = plt.subplots(num_rows, num_cols, figsize=(14, 14))

model.eval()
predictions = model(images.to(device))
scores = nn.functional.softmax(predictions, dim=-1)
predicted_classes = torch.argmax(scores, dim=-1)
# actually if we only need the index of the class with the highest probability, we could omit the softmax operation and perform argmax on the logits directly.
# predicted_classes = torch.argmax(predictions, dim=-1)

for i in range(num_test_samples):
    image, label = images[i], labels[i]
    predicted_class = predicted_classes[i].cpu().item()
    
    # convert the pytorch tensor back to a PIL image
    image = to_pil_image(image)
    
    ax = axes[i//num_cols, i%num_cols]
    ax.imshow(image)
    ax.set_title(f"Prediction: {predicted_class}, gt: {label}", fontdict={"fontsize": 14, "color": ("green" if predicted_class == label else "red")})
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Tasks

# %% [markdown]
# The tasks are now to combat the overfitting with data augmentation, normalization and/or regularization. For each of the following tasks, copy this notebook and rename it according to the task:
# - Modify the `train_transform` to perform a random rotation of the image before passing it to ToTensor. You can use the [RandomRotation](https://pytorch.org/docs/stable/torchvision/transforms.html#torchvision.transforms.RandomRotation) class for this. To combine the rotation transform with the `ToTensor` transform, use the [Compose](https://pytorch.org/docs/stable/torchvision/transforms.html#torchvision.transforms.Compose) class. Make sure to only modify `train_transform` and not `val_transform`, as we do not want to perform random rotations on the validation set.
# - Introduce a weight decay (L2 penalty) of 0.001 by passing a `weight_decay` parameter to the Adam optimizer. See [Adam documentation](https://pytorch.org/docs/stable/optim.html#torch.optim.Adam).
# - Modify the network structure to perform BatchNormalization after each convolution operation. You can use the [BatchNorm2d](https://pytorch.org/docs/stable/nn.html#torch.nn.BatchNorm2d) class for this.
# - Modify the network structure by adding a Dropout layer between the linear layers. Use a dropout probability of 50%. You can use the  [Dropout](https://pytorch.org/docs/stable/nn.html#torch.nn.Dropout) class for this.
#
# In each notebook, adjust the name of the pickle file in the following code:

# %%
import pickle
with open("4_batch-norm.pickle", "wb") as f:
    pickle.dump([train_losses, val_losses], f)

# %% [markdown]
# Then, you can compare the results of the different methods to combat overfitting:

# %%
import glob

plt.figure(figsize=(10, 10))
for f in sorted(glob.glob('*.pickle')):
    with open(f, 'rb') as handle:
        train_losses, val_losses = pickle.load(handle)
    label = " ".join(f.split('.')[0].split('_')[1:])
    plt.plot(train_losses, '--', label=f"{label} (train)")
    plt.plot(val_losses, label=f"{label} (val)")

# plt.yscale('log')
plt.legend()
plt.show()

# %% [markdown]
# You can get the "everything" graph by creating a notebook that combines the changes of all four tasks.

# %% [markdown]
# We can see that all of the above changes decrease the final validation loss. We get the highest reduction when combining all changes, as they all help to combat overfitting and aid generalization.

# %% [markdown]
# ## Bonus tasks

# %% [markdown]
# - In practise, you will often work with custom data formats and thus have to implement custom transforms to perform data augmentation on your data. Creating a custom transform is quite easy. For this task, code the random image rotation transformation in your own custom transform class. You can use the following code to get started:
# ```python
# class MyTransform(object):
#     def __init__(self, arguments):
#         # initialization code here
#         pass
#
#     def __call__(self, sample):
#         # This method gets called on each sample
#         # apply transform to the image
#         # sample is a tuple with (image, label)
#         pass
# ```
# You can use the `.rotate` method of the PIL image to rotate it by a given number of degrees, which you can choose randomly using the `random` module.
# - Instead of using the `weight_decay` parameter of your favorite optimizer, switch out the PyTorch Adam optimizer for an optimizer implementation from the last exercise, and add a L2 penalty to the loss calculation.
# - Switch out the MNIST dataset for the FashionMNIST dataset (also included in torchvision)
# - Remove the limit of 100 samples, and see how your model performs on the full dataset.
